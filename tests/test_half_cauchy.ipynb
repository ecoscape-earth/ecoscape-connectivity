# %%
import sys
sys.path.insert(0, '..')
import ecoscape_connectivity as eco

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
hc = eco.half_cauchy(40, 160)

# %%
# Generate a histogram of samples drawn from the half-Cauchy distribution hc. 
# The histogram is saved as a PNG file.
samples = [hc() for i in range(4000)]

# Plot histogram of the samples
plt.hist(samples, bins=161, alpha=0.75)
plt.title('Histogram of Samples from Half-Cauchy Distribution')
plt.xlabel('Sample values')
plt.ylabel('Frequency')
plt.show()
